# %%
from langchain_core.prompts import (
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate
)
# Out:
# ---------------------------------------------------------------------------
# ConfigError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from langchain_core.prompts import (
#       2     SystemMessagePromptTemplate,
#       3     AIMessagePromptTemplate,
#       4     HumanMessagePromptTemplate
#       5 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\prompts\__init__.py:27
#       1 """**Prompt** is the input to the model.
#       2
#       3 Prompt is often constructed
#    (...)     25
#      26 """  # noqa: E501
# ---> 27 from langchain_core.prompts.base import (
#      28     BasePromptTemplate,
#      29     aformat_document,
#      30     format_document,
#      31 )
#      32 from langchain_core.prompts.chat import (
#      33     AIMessagePromptTemplate,
#      34     BaseChatPromptTemplate,
#    (...)     39     SystemMessagePromptTemplate,
#      40 )
# ...

# %%
system_template_text="你是一位专业的翻译，能够将{input_language}翻译成{output_language}，并且输出文本会根据用户要求的任何语言风格进行调整。请只输出翻译后的文本，不要有任何其它内容。"
system_prompt_template = SystmMessagePromptTemplate.from_template(system_template_text)

# %%
system_prompt_template.input_varaibles
