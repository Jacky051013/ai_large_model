# %% [markdown]
# 背景：某个电商平台需要计算用户购物车中商品的总价格，并给出打折后的结果。
# 题目描述：编写一个程序，根据购物车中每个商品的价格列表，计算总价格和打八折后的价格，并打印出来。购物车里商品价格分别为：50, 30, 25, 15, 40。

# %%
price = [50, 30, 25, 15, 40]
total_price = sum(price)

# %%
discount_total = total_price * 0.8
print(f"total price is {total_price}")
print(f"price after discount is {discount_total}")
# Out:
# total price is 160
# price after discount is 128.0

# %% [markdown]
# _______________________________________________________________________________________________________________________________________________________

# %%
背景：某个学生成绩管理系统需要计算学生的平均成绩和最高分。  
题目描述：编写一个程序，根据学生的成绩列表，计算平均成绩和最高分。学生成绩分别为：85, 92, 78, 89, 94。

# %%
grade = [85, 92, 78, 89, 94]
avg = sum(grade)/len(grade)

# %%
max = max(grade)

# %%
print("the avg: ", avg)
print("the max: ", max)
# Out:
# the avg:  87.6
# the max:  94

# %% [markdown]
#  ---

# %% [markdown]
# 背景：某商场正在举行打折促销活动，现需要编写一个程序来计算顾客购买商品的实际支付金额。
# 题目描述：编写一个程序，输入商品的原价和折扣（以百分比表示），计算并输出顾客需要支付的金额。
# 提示：折后价 = 原价 × (1 - 折扣百分比/100）
# 示例：
# > 请输入商品的原价：300
# 请输入折扣（以百分比表示）：20
# 顾客需要支付的金额为： 240.0

# %%
original_price = float(input("please input the original price: "))
discount_percentage = float(input("please input the discount: "))
pay = original_price * (1 - discount_percentage/100)
print(f"you have to pay: {pay}")
# Out:
# please input the original price:  300
# please input the discount:  20
# you have to pay: 240.0

# %% [markdown]
#  ---

# %% [markdown]
# 背景：为了提高公司员工的工作积极性，公司决定给每位员工根据其工作表现发放奖金。
# 题目描述：编写一个程序，输入员工的工作评分（以整数表示），根据评分计算并输出员工应获得的奖金金额。其中评分高于或等于90，奖金为500。评分高于或等于80，奖金为300。评分高于或等于70，奖金为100。低于70，奖金为0。
# 示例：
# > 请输入员工的工作评分：82
# 员工应获得的奖金金额为： 300

# %%
score = int(input("please input worker score: "))
if score >= 90:
    prize = 500
elif score >= 80:
    prize = 300
elif score >= 70:
    prize = 100
else:
    prize = 0
print("your prize is: ", prize)
# Out:
# please input worker score:  82
# your prize is:  300

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个游戏需要判断玩家是否具备升级的条件。
# 题目描述：编写一个程序，用户输入玩家等级和金币数量，以此判断玩家的等级是否达到升级的要求。如果玩家等级大于等于50级且拥有至少10000金币，可以进行升级，否则则不行。
# 示例：
# > 请输入玩家等级：35
# 请输入玩家金币数量：12005
# 不符合升级条件

# %%
level = int(input("please input level: "))
coin = int(input("please input coins: "))
if level >= 50 and coin >= 10000:
    upgrade = True
    print(upgrade)
else:
    upgrade = False
    print(upgrade)
# Out:
# please input level:  35
# please input coins:  12005
# False

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个系统为了提高安全性，要求用户输入的验证码必须是正确的。
# 题目描述：编写一个程序，自定义一个4位数的验证码，然后接收用户的输入，判断用户输入的验证码是否正确。如果用户输入的验证码与系统生成的验证码一致，则输出验证通过。
# 示例：
# 假如系统内储存的验证码是1234，
# > 请输入验证码：1234
# 验证通过

# %%
code = 1234
password = int(input("please input your password: "))
if password == code:
    print("pass")
else:
    print("fail")
# Out:
# please input your password:  1234
# pass

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个游戏中，玩家需要通过回答问题来获得奖励。
# 题目描述：编写一个程序，根据问题字典，判断玩家回答的问题是否正确。如果玩家同时回答了所有问题且答案全部正确，则给予奖励。
# 问题字典的例子：
# ```python
# questions = {
#     "1. 2+2等于几？": "4",
#     "2. 地球是圆还是扁？": "圆",
#     "3. 西瓜是蔬菜还是水果？": "水果"
# }
# ```
# 示例：
# > 1. 2+2等于几？4
# 2. 地球是圆还是扁？圆
# 3. 西瓜是蔬菜还是水果？水果
# 回答正确，给予奖励

# %%
questions = {
    "1. 2+2等于几？": "4",
    "2. 地球是圆还是扁？": "圆",
    "3. 西瓜是蔬菜还是水果？": "水果"
}

all_correct = True
answer_all = True

for question, answer in questions.items():
    user_answer = input(question)
    if user_answer != answer:
        all_correcct = False
    if user_answer == "":
        answer_all = False

if all_correct and answer_all:
    print("correct")
else:
    print("wrong")
# Out:
# 1. 2+2等于几？ 4
# 2. 地球是圆还是扁？ 圆
# 3. 西瓜是蔬菜还是水果？ 水果
# correct

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个餐厅需要统计每天就餐人数并计算平均每桌就餐人数。
# 题目描述：编写一个程序，输入每桌就餐人数，统计总就餐人数和平均每桌就餐人数，直到输入-1结束统计。
# 示例：
# > 请输入每桌就餐人数（输入-1结束统计）：2
# 请输入每桌就餐人数（输入-1结束统计）：5
# 请输入每桌就餐人数（输入-1结束统计）：3
# 请输入每桌就餐人数（输入-1结束统计）：4
# 请输入每桌就餐人数（输入-1结束统计）：2
# 请输入每桌就餐人数（输入-1结束统计）：4
# 请输入每桌就餐人数（输入-1结束统计）：-1
# 总就餐人数： 20
# 平均每桌就餐人数： 3.3333333333333335

# %%
total = 0
table = 0
while True:
    num = int(input("please enter the number of people: "))
    if num == -1:
        break
    total += num
    table = table + 1

avg = total/table
print(f"AVG = {avg}")
# Out:
# please enter the number of people:  2
# please enter the number of people:  5
# please enter the number of people:  3
# please enter the number of people:  4
# please enter the number of people:  2
# please enter the number of people:  4
# please enter the number of people:  -1
# AVG = 3.3333333333333335

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个音乐播放器需要循环播放指定的歌曲列表。
# 题目描述：编写一个程序，当用户输入“下一首”时，按照顺序循环播放歌曲列表，直到用户输入“停止”，表明要求停止播放。
# 歌曲列表的例子：
# ```python
# songs = ["歌曲1", "歌曲2", "歌曲3"]
# ```
# 示例：
# > 正在播放歌曲： 歌曲1
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：下一首
# 正在播放歌曲： 歌曲2
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：下一首
# 正在播放歌曲： 歌曲3
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：下一首
# 正在播放歌曲： 歌曲1
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：下一首
# 正在播放歌曲： 歌曲2
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：-
# 正在播放歌曲： 歌曲2
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：-
# 正在播放歌曲： 歌曲2
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：下一首
# 正在播放歌曲： 歌曲3
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放：停止

# %%
songs = ["歌曲1", "歌曲2", "歌曲3"]
playing = True
index = 0
while playing:
    print("playing" + songs[index])
    user_input = input("输入'下一首'播放下一首歌曲，输入'停止'停止播放：")
    if user_input == "下一首":
        index = (index + 1)%len(songs)
    elif user_input == "停止":
        print("stop")
        playing = False
# Out:
# playing歌曲1
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放： 下一首
# playing歌曲2
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放： 下一首
# playing歌曲3
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放： 下一首
# playing歌曲1
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放： -
# playing歌曲1
# 输入'下一首'播放下一首歌曲，输入'停止'停止播放： 停止
# stop

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个学校需要统计每个班级的学生人数并计算总学生人数。
# 题目描述：编写一个程序，先询问所有班级的数量，然后让用户输入各个班级的学生人数，从而统计所有班级的总学生人数。
# 示例：
# > 请输入班级数量：5
# 请输入第 1 个班级的学生人数：39
# 请输入第 2 个班级的学生人数：42
# 请输入第 3 个班级的学生人数：41
# 请输入第 4 个班级的学生人数：40
# 请输入第 5 个班级的学生人数：42
# 总学生人数： 204

# %%
class_num = int(input("please input the number of class: "))
class_list = []
numclass = 0
while len(class_list) < class_num:
    numclass += 1
    class_list.append(int(input(f"please input the number of people in class{numclass}")))
sum_of_student = sum(class_list)
print("total students: " , sum_of_student)
# Out:
# please input the number of class:  5
# please input the number of people in class1 39
# please input the number of people in class2 42
# please input the number of people in class3 41
# please input the number of people in class4 40
# please input the number of people in class5 42
# total students:  204

# %%
total_students = 0
class_count = int(input("请输入班级数量："))

for i in range(1, class_count + 1):
    student_count = int(input("请输入第 {} 个班级的学生人数：".format(i)))
    total_students += student_count

print("总学生人数：", total_students)

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个学生管理系统需要将学生信息保存到文件中。
# 题目描述：编写一个程序，用户可以在输入一个学生的姓名和年龄，将其保存到一个文本文件中。
# 示例：
# > 请输入学生姓名：粒粒
# 请输入学生年龄：5
# 学生信息已保存到文件。

# %%
name = input("please input your name: ")
age = input("please input your age: ")
with open("stuednt.txt", "w", encoding = "utf-8") as f:
    f.write(f"{name}/n")
    f.write(f"{age}/n")

print("store!")
# Out:
# please input your name:  粒粒
# please input your age:  5
# store!

# %% [markdown]
# 背景：某个日志系统需要将用户的操作记录保存到日志文件中。
# 题目描述：编写一个程序，输入用户的操作记录，将其保存到一个日志文件中（每条记录占一行）。
# 示例：
# > 请输入操作记录：打开文件
# 操作记录已保存到日志文件。

# %%
with open("action.txt", "w", encoding = "utf-8") as f:
    f.write(f"{input("请输入操作记录: ")}/n")

print("操作记录已保存到日志文件")
# Out:
# 请输入操作记录:  打开文件
# 操作记录已保存到日志文件

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个日程管理系统需要读取用户的日程安排。
# 题目描述：编写一个程序，读取名为"schedules.txt"的文本文件，逐行打印出其中的日程安排。

# %%
with open("schedules.txt", "r", encoding = "utf-8") as f:
    lines = f.readlines()
for line in lines:
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 with open("schedules.txt", "r", encoding = "utf-8") as f:
#       2     lines = f.readlines()
#       3 for line in lines:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'schedules.txt'

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个计算器程序需要处理除零错误。
# 题目描述：编写一个程序，输入两个数进行除法运算，如果除数为零，则捕获异常并输出错误提示。
# 示例一：
# > 请输入被除数：5
# 请输入除数：8
# 结果： 0.625
#
# 示例二：
# > 请输入被除数：23
# 请输入除数：0
# 除数不能为零

# %%
try:
    dividend = int(input("请输入被除数："))
    divisor = int(input("请输入除数："))
    result = dividend / divisor
    print("结果：", result)
except ZeroDivisionError:
    print("除数不能为 0")
# Out:
# 请输入被除数： 23
# 请输入除数： 0
# 除数不能为 0

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个文件读取程序需要处理文件不存在的情况。
# 题目描述：编写一个程序，读取名为"data.txt"的文件内容，如果文件不存在，则捕获异常并输出错误提示：“文件不存在，请检查文件名”。

# %%
try:
    with open("data.txt", "r") as file:
        content = file.read()

    print(content)
except FileNotFoundError:
    print("文件不存在，请检查文件名")
# Out:
# 文件不存在，请检查文件名

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个图书管理系统需要管理图书馆中的书籍信息。
# 题目描述：创建一个Book类，包含图书的属性（书名 `title`、作者 `author`、出版年份 `year`）和方法（展示图书信息 `display_info`，用于打印所有属性的信息）。然后再创建一个Book类的实例，并调用`display_info`方法，来打印该书籍的信息。

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def display_info(self):
        print(f"title: {self.title},\nauthor: {self.author},\nyear: {self.year}\n")

book1 = Book("abc", "def", "2026")
book1.display_info()
# Out:
# title: abc,
# author: def,
# year: 2026

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个几何图形计算程序需要计算圆的相关信息。
# 题目描述：设计一个Circle类，包含圆的属性（半径 `radius`）和方法（计算周长和面积 `calculate_circumference` 和 `calculate_area`）。然后再创建一个Circle类的实例，并调用方法分别计算周长和面积，并进行打印。

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def calculate_circumference(self):
        return 2 * math.pi * self.radius

    def calculate_area(self):
        return math.pi * self.radius**2

circle = Circle(5)
print(circle.calculate_circumference())
print(circle.calculate_area())
# Out:
# 31.41592653589793
# 78.53981633974483

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个矩形计算程序需要计算矩形的相关信息。
# 题目描述：设计一个Rectangle类，包含矩形的属性（长 `length` 和宽 `width`）和方法（计算周长和面积 `calculate_perimeter` 和 `calculate_area`）。设计一个Rectangle类，并调用方法分别计算周长和面积，并进行打印。

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

    def calculate_area(self):
        return self.length * self.width

rectangle = Rectangle(4, 6)
print(rectangle.calculate_perimeter())
print(rectangle.calculate_area())
# Out:
# 20
# 24

# %% [markdown]
#  ----

# %% [markdown]
# 背景：某个公司的员工分为正式员工和临时员工。
# 题目描述：设计一个Employee类作为父类，包含员工的基本属性（姓名 `name`、工号 `emp_id`）和方法（展示员工信息，即姓名和工号 `display_info`）。然后设计一个RegularEmployee类和一个TemporaryEmployee类，分别继承自Employee类，但它们各自有额外的属性和方法。具体来说，RegularEmployee的员工有部门属性 `department`，TemporaryEmployee的员工有项目属性 `project`，并且它们各自的`display_info`方法也会把独有的部门或项目信息打印出来。

# %%
class Employee:
    def __init__(self, name, emp_id):
        self.name = name
        self.emp_id = emp_id

    def display_info(self):
        print(f"name:{self.name}\nemp_id:{self.emp_id}")

class RegularEmployee(Employee):
    def __init__(self, name, emp_id, department):
        super().__init__(name, emp_id)
        self.department = department

    def display_info(self):
        super().display_info()
        print(f"department:{self.department}\n")

class TemporaryEmployee(Employee):
    def __init__(self, name, emp_id, project):
        super().__init__(name, emp_id)
        self.project = project

    def display_info(self):
        super().display_info()
        print(f"project:{self.project}\n")

regular_employee = RegularEmployee("Jacky", 1001, "digit_department")
regular_employee.display_info()
temporary_employee = TemporaryEmployee("Phare", 1002, "finance_project")
temporary_employee.display_info()
# Out:
# name:Jacky
# emp_id:1001
# department:digit_department
#
# name:Phare
# emp_id:1002
# project:finance_project
