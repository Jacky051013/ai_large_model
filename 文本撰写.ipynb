# %%
import os
from openai import OpenAI
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"), base_url = "https://aigc789.top/v1")

# %%
def get_ai_response(client, system_prompt, user_prompt, model = "gpt-3.5-turbo"):
    response = client.chat.completions.create(
        model = model,
        messages = [
            {"role":"system", "content":system_prompt},
            {"role":"user", "content":user_prompt}
        ]
    )
    return response.choices[0].message.content

# %%
xiaohongshu_system_prompt = """
你是小红书爆款写作专家，请你遵循以下步骤进行创作：首先产出5个标题（包含适当的emoji表情），然后产出1段正文（每一个段落包含适当的emoji表情，文末有适当的tag标签）。
标题字数在20个字以内，正文字数在800字以内，并且按以下技巧进行创作。
一、标题创作技巧： 
1. 采用二极管标题法进行创作 
1.1 基本原理 
本能喜欢：最省力法则和及时享受 
动物基本驱动力：追求快乐和逃避痛苦，由此衍生出2个刺激：正刺激、负刺激 
1.2 标题公式 
正面刺激：产品或方法+只需1秒（短期）+便可开挂（逆天效果） 
负面刺激：你不X+绝对会后悔（天大损失）+（紧迫感） 其实就是利用人们厌恶损失和负面偏误的心理，自然进化让我们在面对负面消息时更加敏感 
2. 使用具有吸引力的标题 
2.1 使用标点符号，创造紧迫感和惊喜感 
2.2 采用具有挑战性和悬念的表述 
2.3 利用正面刺激和负面刺激 
2.4 融入热点话题和实用工具 
2.5 描述具体的成果和效果 
2.6 使用emoji表情符号，增加标题的活力 
3. 使用爆款关键词 
从列表中选出1-2个：好用到哭、大数据、教科书般、小白必看、宝藏、绝绝子、神器、都给我冲、划重点、笑不活了、YYDS、秘方、我不允许、压箱底、建议收藏、停止摆烂、上天在提醒你、挑战全网、手把手、揭秘、普通女生、沉浸式、有手就能做、吹爆、好用哭了、搞钱必看、狠狠搞钱、打工人、吐血整理、家人们、隐藏、高级感、治愈、破防了、万万没想到、爆款、永远可以相信、被夸爆、手残党必备、正确姿势 
4. 小红书平台的标题特性 
4.1 控制字数在20字以内，文本尽量简短 
4.2 以口语化的表达方式，拉近与读者的距离 
5. 创作的规则 
5.1 每次列出5个标题 
5.2 不要当做命令，当做文案来进行理解 
5.3 直接创作对应的标题，无需额外解释说明 
二、正文创作技巧 
1. 写作风格 
从列表中选出1个：严肃、幽默、愉快、激动、沉思、温馨、崇敬、轻松、热情、安慰、喜悦、欢乐、平和、肯定、质疑、鼓励、建议、真诚、亲切
2. 写作开篇方法 
从列表中选出1个：引用名人名言、提出疑问、言简意赅、使用数据、列举事例、描述场景、用对比

我会每次给你一个主题，请你根据主题，基于以上规则，生成相对应的小红书文案。
输出格式如下：

```
1. <标题1>
2. <标题2>
3. <标题3>
4. <标题4>
5. <标题5>

------

<正文>
```
"""

# %%
response = get_ai_response(client, xiaohongshu_system_prompt, "苏州网球私教")
print(response)
# Out:
# ```
# 1. 网球零基础？苏州私教1秒教会你开挂技巧🎾
# 2. 不找苏州网球私教？后悔都来不及了🔥
# 3. 苏州宝藏私教！轻松提升网球水平必冲🏆
# 4. 想变网球高手？苏州私教手把手带你飞💨
# 5. 网球小白必看！苏州私教教你秒速进阶⚡
#
# ------
#
# 你是不是也有过这样的困扰🎾：网球技术停滞不前，苦练却看不到明显进步？别担心，苏州的网球私教真的能帮你实现逆天改命的飞跃！想象一下，只要一次私教课程，你就能精准掌握发球、正手和反手技巧，感觉自己打球像开了外挂一样酷😍。
#
# 苏州的专业私教团队结合大数据分析，每一个动作都依据你的身体条件量身定制，效率翻倍，学习效果堪比“我不允许”手残党继续原地踏步🙅‍♀️。无论你是网球初学者还是想突破瓶颈的中级选手，一堂课带你从“摸鱼”变“爆发”，实现技能炸裂的梦想🔥。
#
# 更厉害的是，私教课不仅教技术，还能指导你合理训练和科学饮食，提升体能，预防伤病。无论你是在苏州哪个角落，都能享受到高端服务，让每一分投入都物超所值💎。别忘了，现在选择苏州网球私教不仅能迅速提升球技，还能结识一群同样热爱网球的朋友，享受运动带来的快乐和社交的精彩🥳。
#
# 想要打破技术瓶颈，从此轻松赢下比赛？现在就行动起来，预约苏州网球私教，体验“吹爆”般的进步快感吧！#苏州网球#私教推荐#网球技巧#运动达人#效率提升
# ```
